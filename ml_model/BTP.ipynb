# %% [markdown]
# Data source: https://www.kaggle.com/robikscube/hourly-energy-consumption
#
# Reference paper: https://www.researchgate.net/publication/256089416_Modelling_Using_Polynomial_Regression

# %%
import csv
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## **Function to read data from csv file**

# %%
def load_data():

    array = []

    with open('AEP_hourly.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        line_count = 0
        for row in csv_reader:
            array.append(row)
    

    array = array[24:]
    array = [[i[0][-8:], float(i[1])] for i in array]

    array = [[1 + 4 * int(i[0][:2]), i[1]] for i in array]
    array1 = []
    element = []

    for i in array:
      element.append(i)
      if i[0] == 93:
          array1.append(element)
          element = []
    
    output_array = []

    for i in array1:
      if len(i) == 24: # Remove days which do not have the data of all days (31 such days exist)
        output_array.append(i)

    return output_array

# %%
array = load_data()
print(array)
# Out:
# [[[1, 12892.0], [5, 14097.0], [9, 13667.0], [13, 13451.0], [17, 13379.0], [21, 13506.0], [25, 14121.0], [29, 15066.0], [33, 15771.0], [37, 16047.0], [41, 16245.0], [45, 16377.0], [49, 16138.0], [53, 15886.0], [57, 15503.0], [61, 15206.0], [65, 15049.0], [69, 15161.0], [73, 16085.0], [77, 16508.0], [81, 16306.0], [85, 16223.0], [89, 15931.0], [93, 15207.0]], [[1, 14316.0], [5, 15223.0], [9, 14731.0], [13, 14503.0], [17, 14432.0], [21, 14531.0], [25, 15087.0], [29, 16018.0], [33, 16968.0], [37, 17149.0], [41, 17261.0], [45, 17194.0], [49, 17011.0], [53, 16749.0], [57, 16546.0], [61, 16403.0], [65, 16161.0], [69, 16380.0], [73, 17330.0], [77, 17738.0], [81, 17468.0], [85, 17093.0], [89, 16736.0], [93, 15984.0]], [[1, 14900.0], [5, 17580.0], [9, 17158.0], [13, 17002.0], [17, 16923.0], [21, 17191.0], [25, 17908.0], [29, 18944.0], [33, 19752.0], [37, 19882.0], [41, 19544.0], [45, 19309.0], [49, 18756.0], [53, 18201.0], [57, 17666.0], [61, 17203.0], [65, 16935.0], [69, 17207.0], [73, 18349.0], [77, 18815.0], [81, 18599.0], [85, 18480.0], [89, 18135.0], [93, 17112.0]], [[1, 16047.0], [5, 16718.0], [9, 16150.0], [13, 16090.0], [17, 16223.0], [21, 16652.0], [25, 17317.0], [29, 18384.0], [33, 19366.0], [37, 19772.0], [41, 19792.0], [45, 19697.0], [49, 19193.0], [53, 18640.0], [57, 18066.0], [61, 17692.0], [65, 17522.0], [69, 17933.0], [73, 19353.0], [77, 20046.0], [81, 20127.0], [85, 20049.0], [89, 19751.0], [93, 19038.0]], [[1, 18133.0], [5, 15059.0], [9, 14617.0], [13, 14452.0], [17, 14465.0], [21, 14561.0], [25, 14862.0], [29, 15318.0], [33, 15865.0], [37, 16421.0], [41, 16751.0], [45, 16521.0], [49, 16047.0], [53, 15790.0], [57, 15702.0], [61, 15488.0], [65, 15607.0], [69, 16012.0], [73, 17243.0], [77, 17922.0], [81, 18064.0], [85, 18086.0], [89, 17834.0], [93, 17392.0]], [[1, 16842.0], [5, 16669.0], [9, 16218.0], [13, 16135.0], [17, 16107.0], [21, 16229.0], [25, 16470.0], [29, 16935.0], [33, 17548.0], [37,
0, 20840.0, 20670.0, 20300.0], [19719.0, 16053.0, 15562.0, 15439.0, 15498.0, 15743.0, 16126.0, 16793.0, 17583.0, 18108.0, 18035.0, 17599.0, 17022.0, 16390.0, 15921.0, 15619.0, 15475.0, 16039.0, 17080.0, 17479.0, 17431.0, 17458.0, 17162.0, 16561.0], [15645.0, 15893.0, 15503.0, 15315.0, 15264.0, 15596.0, 16544.0, 18227.0, 19281.0, 19052.0, 18758.0, 18254.0, 17654.0, 17236.0, 16818.0, 16450.0, 16250.0, 16581.0, 17953.0, 18650.0, 18653.0, 18645.0, 18444.0, 17832.0], [16906.0, 17381.0, 17048.0, 16862.0, 16876.0, 17185.0, 18127.0, 19901.0, 20605.0, 20312.0, 19945.0, 19364.0, 18559.0, 17977.0, 17693.0, 17396.0, 17246.0, 17669.0, 18921.0, 19446.0, 19506.0, 19477.0, 19068.0, 18062.0], [16826.0, 17126.0, 16709.0, 16618.0, 16546.0, 16905.0, 17889.0, 19542.0, 20491.0, 20295.0, 19843.0, 19422.0, 19050.0, 18519.0, 18301.0, 17748.0, 17696.0, 18153.0, 19645.0, 20441.0, 20502.0, 20486.0, 20274.0, 19304.0], [18139.0, 16704.0, 16281.0, 16064.0, 16155.0, 16500.0, 17338.0, 18923.0, 19920.0, 19679.0, 19432.0, 19293.0, 19182.0, 19022.0, 18917.0, 18750.0, 18749.0, 19204.0, 20431.0, 20996.0, 20837.0, 20689.0, 20285.0, 19248.0], [18021.0, 14308.0, 14116.0, 14021.0, 14052.0, 14408.0, 15501.0, 17190.0, 18404.0, 18474.0, 18536.0, 18575.0, 18493.0, 18435.0, 18492.0, 18438.0, 18484.0, 18945.0, 20103.0, 20564.0, 20447.0, 20311.0, 19814.0, 18762.0], [17504.0, 14153.0, 13683.0, 13427.0, 13373.0, 13460.0, 13704.0, 14157.0, 14 ...

# %%
print(len(x))
# Out:
# 5022

# %%
y = np.array(y)

# %%
y = np.amax(y)
# Out:
# 25695.0

# %% [markdown]
# #### **Scaling the data**

# %%
y = 150 + (y / np.amax(y)) * 50

# %%
y = y.tolist()

# %%
print(y.size)
# Out:
# 120528

# %%
print(len(x))
print(len(y))
# Out:
# 5053
# 5053

# %% [markdown]
# #### **Function to plot the data**

# %%
def plotting_function(ind):
  global x, y
  plt.grid(True)
  plt.xlabel("Block Number")
  plt.ylabel("Actual Generation (AG)")
  plt.plot(x[ind], y[ind])
  plt.show()

# %% [markdown]
# ## **Observing the Data**

# %%
plotting_function(0)

# %%
plotting_function(1)

# %%
plotting_function(2)

# %%
plotting_function(3)

# %%
Dplotting_function(4)

# %%
plotting_function(5)

# %%
plotting_function(6)

# %%
plotting_function(7)

# %%
plotting_function(8)

# %%
plotting_function(9)

# %% [markdown]
# **Conclusions: The data has 3 peaks: around the 5th, 40th, and the 80th block. The data also resembles a polynomial function**
#
# **Result: Polynomial regression to be used**

# %% [markdown]
# ## **Polynomial Regression**

# %%
def polynomial_regression(X, Y, N):
  """Generalized function for polynomial regression of N degree
  X and Y are numpy.ndarray, N is the degree of the required polynomial function"""

  input_matrix = [] # Square matrix of order (N+1)
  k = 0
  for i in range(N+1):
    input_matrix.append([sum(X ** (i + j)) for j in range(N+1)])
    k += 1
  
  input_matrix = np.array(input_matrix)

  output_matrix = []
  for i in range(N+1):
    output_matrix.append([sum(Y * (X ** i))])
  
  output_matrix = np.array(output_matrix)

  parameter_matrix = np.matmul(np.linalg.inv(input_matrix), output_matrix)
  
  def regression_function(X_i):
    total = 0
    for i in range(len(parameter_matrix)):
      total += (X_i ** i) * parameter_matrix[i]

    return total

  return regression_function

# %% [markdown]
# #### **Testing the function for a single day**

# %%
plt.plot(day1_x, regression_2(day1_x))
plt.plot(day1_x, day1_y)
plt.show()

# %%
regression_3 = polynomial_regression(day1_x, day1_y, 3)

# %%
plt.plot(day1_x, regression_3(day1_x))
plt.plot(day1_x, day1_y)
plt.show()

# %%
regression_4 = polynomial_regression(day1_x, day1_y, 4)
plt.plot(day1_x, regression_4(day1_x))
plt.plot(day1_x, day1_y)
plt.show()

# %%
regression_5 = polynomial_regression(day1_x, day1_y, 5)
plt.plot(day1_x, regression_5(day1_x))
plt.plot(day1_x, day1_y)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in long_scalars

# %%
regression_6 = polynomial_regression(day1_x, day1_y, 6)
plt.plot(day1_x, regression_6(day1_x))
plt.plot(day1_x, day1_y)
plt.xlabel("Block Number")
plt.ylabel("Actual Generation (MW)")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in long_scalars

# %%
regression_7 = polynomial_regression(day1_x, day1_y, 7)
plt.plot(day1_x, regression_7(day1_x))
plt.plot(day1_x, day1_y)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in long_scalars

# %%
regression_8 = polynomial_regression(day1_x, day1_y, 7)
plt.plot(day1_x, regression_7(day1_x))
plt.plot(day1_x, day1_y)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in long_scalars

# %%
regression_9 = polynomial_regression(day1_x, day1_y, 9)
plt.plot(day1_x, regression_9(day1_x))
plt.plot(day1_x, day1_y)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in long_scalars

# %% [markdown]
# **Conclusion: the function is working correctly. We can use it to implement our model.**

# %% [markdown]
# ## **Training the model**

# %% [markdown]
# #### Function to split the data into training and testing sets

# %%
def train_test_split(arr, percent):
  """Splits an array into train and test set)"""
  L = len(arr) - 1
  last = int(L * percent / 100)

  return (arr[:last]), (arr[last:])

# %%
x_train, x_test = train_test_split(x, 20)
y_train, y_test = train_test_split(y, 20)

# %% [markdown]
# #### Training the model

# %%
x_train, y_train = np.array(x_train), np.array(y_train)
x_train, y_train = x_train.flatten(), y_train.flatten()

# %%
print(len(x_train), len(y_train))
# Out:
# 24096 24096

# %% [markdown]
# ### **Array to store functions for degree 0 to 9**: Using this we will be able to call our prediction function of degree n using the array's nth index element i.e. array[n]

# %%
regression = [polynomial_regression(x_train, y_train, i) for i in range(10)]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in long_scalars

# %%
x_test, y_test = np.array(x_test), np.array(y_test)

# %% [markdown]
# ## **Prediction**

# %% [markdown]
# The model performs prediction for a certain day in the test dataset. The degree of the predicted polynomial function and the day can be conveniently changed by changing the value of these parameters

# %%
TEST_DAY, DEGREE = 5, 4

plt.plot(x_test[TEST_DAY], regression[DEGREE](x_test[TEST_DAY]))
plt.plot(x_test[TEST_DAY], y_test[TEST_DAY])
plt.grid(True)
plt.legend(["Predicted Value", " Actual Value"])
plt.xlabel("Block Number")
plt.ylabel("Actual Generation (MW)")
plt.show()
